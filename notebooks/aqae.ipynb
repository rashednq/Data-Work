# %%
pip install pandas
# Out:
# ...
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/86/41/585a168330ff063014880a80d744219dbf1dd7a1c706e75ab3425a987384/pandas-2.3.3-cp312-cp312-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for numpy>=1.26.0 from https://files.pythonhosted.org/packages/d4/b5/94c1e79fcbab38d1ca15e13777477b2914dd2d559b410f96949d6637b085/numpy-2.4.0-cp312-cp312-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for pytz>=2020.1 from https://files.pythonhosted.org/packages/81/c4/34e93fe5f5429d7570ec1fa436f1986fb1f00c3e0f43a589fe2bbcd22c3f/pytz-2025.2-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for tzdata>=2022.7 from https://files.pythonhosted.org/packages/c7/b0/003792df09decd6849a5e39c28b513c06e84436a54440380862b5aeff25d/tzdata-2025.3-py2.py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB 660.6 kB/s eta 0:00:17
# ...

# %%
pip install bs4
# Out:
# ...
#   Obtaining dependency information for bs4 from https://files.pythonhosted.org/packages/51/bb/bf7aab772a159614954d84aa832c129624ba6c32faa559dfb200a534e50b/bs4-0.0.2-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for beautifulsoup4 from https://files.pythonhosted.org/packages/1a/39/47f9197bdd44df24d67ac8893641e16f386c984a0619ef2ee4c51fbbc019/beautifulsoup4-4.14.3-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for soupsieve>=1.6.1 from https://files.pythonhosted.org/packages/48/f3/b67d6ea49ca9154453b6d70b34ea22f3996b9fa55da105a79d8732227adc/soupsieve-2.8.1-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/107.7 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/107.7 kB ? eta -:--:--
#    -------------- ------------------------ 41.0/107.7 kB 326.8 kB/s eta 0:00:01
#    ------------------------- ------------- 71.7/107.7 kB 491.5 kB/s eta 0:00:01
# ...

# %%
pip install requests
# Out:
# ...
#   Obtaining dependency information for requests from https://files.pythonhosted.org/packages/1e/db/4254e3eabe8020b458f1a747140d32277ec7a271daf1d235b70dc0b4e6e3/requests-2.32.5-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for charset_normalizer<4,>=2 from https://files.pythonhosted.org/packages/3d/2d/1e5ed9dd3b3803994c155cd9aacb60c82c331bad84daf75bcb9c91b3295e/charset_normalizer-3.4.4-cp312-cp312-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for idna<4,>=2.5 from https://files.pythonhosted.org/packages/0e/61/66938bbb5fc52dbdf84594873d5b51fb1f7c7794e9c0f5bd885f30bc507b/idna-3.11-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for urllib3<3,>=1.21.1 from https://files.pythonhosted.org/packages/6d/b9/4095b668ea3678bf6a0af005527f39de12fb026516fb3df17495a733b7f8/urllib3-2.6.2-py3-none-any.whl.metadata
# ...

# %%
pip install httpx
# Out:
# ...
#   Obtaining dependency information for httpx from https://files.pythonhosted.org/packages/2a/39/e50c7c3a983047577ee07d2a9e53faf5a69493943ec3f6a384bdc792deb2/httpx-0.28.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for anyio from https://files.pythonhosted.org/packages/7f/9c/36c5c37947ebfb8c7f22e0eb6e4d188ee2d53aa3880f3f2744fb894f0cb1/anyio-4.12.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for httpcore==1.* from https://files.pythonhosted.org/packages/7e/f5/f66802a942d491edb555dd61e3a9961140fd64c90bce1eafd741609d334d/httpcore-1.0.9-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for h11>=0.16 from https://files.pythonhosted.org/packages/04/4b/29cac41a4d98d144bf5f6d33995617b185d14b22401f75ca86f384e87ff1/h11-0.16.0-py3-none-any.whl.metadata
# ...

# %%
import pandas as pd

df = pd.DataFrame(
    {
        "Location": [
            "شارع محمد نور رحيمي، المهدية، غرب الرياض، الرياض",
            "شارع أبي عروة، المهدية، غرب الرياض، الرياض",
            "النهضة، شمال جدة، جدة"
        ],
        "Type": [
            "Apartment",
            "villa",
            "Apartment"
        ],
        "Number of Bedrooms": [
            3,
            4,
            5
        ],
        "Number of Bathrooms": [
            3,
            5,
            4
        ],
        "price": [
            800000,
            2150000,
            1230000
        ]
    }
)

df
# Out:
#                                            Location       Type  \
# 0  شارع محمد نور رحيمي، المهدية، غرب الرياض، الرياض  Apartment
# 1        شارع أبي عروة، المهدية، غرب الرياض، الرياض      villa
# 2                             النهضة، شمال جدة، جدة  Apartment
#
#    Number of Bedrooms  Number of Bathrooms    price
# 0                   3                    3   800000
# 1                   4                    5  2150000
# 2                   5                    4  1230000

# %%
import httpx

r = httpx.get("https://api.thecatapi.com/v1/images/search?limit=10").json()

df = pd.DataFrame(r)

df
# Out:
#            id                                               url  width  height
# 0         3qu         https://cdn2.thecatapi.com/images/3qu.jpg    500     373
# 1         71d         https://cdn2.thecatapi.com/images/71d.jpg   1024     680
# 2         8b1         https://cdn2.thecatapi.com/images/8b1.jpg    983    1024
# 3         9t5         https://cdn2.thecatapi.com/images/9t5.jpg   1936    2592
# 4         d1k         https://cdn2.thecatapi.com/images/d1k.jpg   1728    1152
# 5  MjA3NDMzMg  https://cdn2.thecatapi.com/images/MjA3NDMzMg.jpg    480     378
# 6   njK25knLH   https://cdn2.thecatapi.com/images/njK25knLH.jpg   1024     823
# 7   vXiNSY60T   https://cdn2.thecatapi.com/images/vXiNSY60T.jpg   3315    1865
# 8   aB3eTwbRQ   https://cdn2.thecatapi.com/images/aB3eTwbRQ.jpg    750     937
# 9   Znj6KEDRX   https://cdn2.thecatapi.com/images/Znj6KEDRX.jpg    261     193

# %%
import requests

cookies = {
    'req-device-token': 'a4bdf11a-9a02-41ca-a466-aef7263aaf4d',
    'webapp_token': '%22Wk6NTixsCmW3wqPo-t2FZtJZhkr7kHu2aAvZO-jqEVoD2x73EOoCgs5MSHaJ2yZTm9zoA3ZaGF3i6cNYDR9jUWMdj6XSQBmLzEDHZJeevZrck-9sRXhQoxZWrosWUhUVSEze8v89GRKsM6YfZc09qFOEKDTAzUZV7FTXNp1-4rcH%22',
    'user_iam_verified': '%22%22',
    'user': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....mdfY1o5hH-fby2FcFxD2ikdN9_pQQDo5Yp0Fw31WvvE',
    '__cf_bm': '_YYtfdl.3q02Ru.KNrWc1dI2jWogwtaiHssxTbCV9nc-1766671966-1.0.1.1-urj9qxCz5RrtfvZv4SkOocBWCt.ls1S4vzpD9OQ1DAnKCE5pBOfQ82K333NA9rT8UcHJHmy.GHu7yLVXU5_S8PLtBFCZ63tCfml72MU3OxY',
    'cf_clearance': 'LlYF90JQKUIaAif2RkxpgR6d_gJlw0Y438oSNiqAvfE-1766672046-1.2.1.1-zCBP9TlgjdEA0zZyjdtzz0s8N6oRCYiD5WFHNFE_DIsaDoK6S1SmqfeCx.MiZnueXNUb0Wup5Qo6VtajTMWtgjkHLYgvGbXzhnN4RSqoc2tHmk1cUVRpMOTMwB_CyvUc51vc8VlFs15nnMsnWyHD1MvBsrUXOSZDplRBpb.DnHGghpKENDLGVgXYtMDVf4z.rUQfQT16aRUubFRkyust151pcldWgCOnSu1kn3I6.jE',
}

headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8',
    'accept-language': 'en-US,en;q=0.8',
    'cache-control': 'max-age=0',
    'priority': 'u=0, i',
    'referer': 'https://www.google.com/',
    'sec-ch-ua': '"Brave";v="143", "Chromium";v="143", "Not A(Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'sec-gpc': '1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36',
    # 'cookie': 'req-device-token=a4bdf11a-9a02-41ca-a466-aef7263aaf4d; webapp_token=%22Wk6NTixsCmW3wqPo-t2FZtJZhkr7kHu2aAvZO-jqEVoD2x73EOoCgs5MSHaJ2yZTm9zoA3ZaGF3i6cNYDR9jUWMdj6XSQBmLzEDHZJeevZrck-9sRXhQoxZWrosWUhUVSEze8v89GRKsM6YfZc09qFOEKDTAzUZV7FTXNp1-4rcH%22; user_iam_verified=%22%22; user=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....mdfY1o5hH-fby2FcFxD2ikdN9_pQQDo5Yp0Fw31WvvE; __cf_bm=_YYtfdl.3q02Ru.KNrWc1dI2jWogwtaiHssxTbCV9nc-1766671966-1.0.1.1-urj9qxCz5RrtfvZv4SkOocBWCt.ls1S4vzpD9OQ1DAnKCE5pBOfQ82K333NA9rT8UcHJHmy.GHu7yLVXU5_S8PLtBFCZ63tCfml72MU3OxY; cf_clearance=LlYF90JQKUIaAif2RkxpgR6d_gJlw0Y438oSNiqAvfE-1766672046-1.2.1.1-zCBP9TlgjdEA0zZyjdtzz0s8N6oRCYiD5WFHNFE_DIsaDoK6S1SmqfeCx.MiZnueXNUb0Wup5Qo6VtajTMWtgjkHLYgvGbXzhnN4RSqoc2tHmk1cUVRpMOTMwB_CyvUc51vc8VlFs15nnMsnWyHD1MvBsrUXOSZDplRBpb.DnHGghpKENDLGVgXYtMDVf4z.rUQfQT16aRUubFRkyust151pcldWgCOnSu1kn3I6.jE',
}

response = requests.get('https://sa.aqar.fm/', cookies=cookies, headers=headers)
response.text

html_doc = response.text

from bs4 import BeautifulSoup

assert "You have been blocked" not in response.text

soup = BeautifulSoup(html_doc)

soup
# Out:
# <!DOCTYPE html>
# ...

# %%
pip install joblib
# Out:
# ...
#   Obtaining dependency information for joblib from https://files.pythonhosted.org/packages/7b/91/984aca2ec129e2757d1e4e3c81c3fcda9d0f85b74670a094cc443d9ee949/joblib-1.5.3-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/309.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/309.1 kB ? eta -:--:--
#    - -------------------------------------- 10.2/309.1 kB ? eta -:--:--
#    --- ----------------------------------- 30.7/309.1 kB 640.0 kB/s eta 0:00:01
#    ------- ------------------------------- 61.4/309.1 kB 544.7 kB/s eta 0:00:01
#    ----------- --------------------------- 92.2/309.1 kB 581.0 kB/s eta 0:00:01
#    --------------- ---------------------- 122.9/309.1 kB 599.1 kB/s eta 0:00:01
#    ------------------------- ------------ 204.8/309.1 kB 827.9 kB/s eta 0:00:01
#    ---------------------------- --------- 235.5/309.1 kB 798.9 kB/s eta 0:00:01
#    -------------------------------------- 309.1/309.1 kB 954.7 kB/s eta 0:00:00
# ...

# %%
import requests
from joblib import Memory 
mem=Memory(".joblib_cache")

@mem.cache
def fetch(url):
    cookies = {
        'req-device-token': 'a4bdf11a-9a02-41ca-a466-aef7263aaf4d',
        'webapp_token': '%22Wk6NTixsCmW3wqPo-t2FZtJZhkr7kHu2aAvZO-jqEVoD2x73EOoCgs5MSHaJ2yZTm9zoA3ZaGF3i6cNYDR9jUWMdj6XSQBmLzEDHZJeevZrck-9sRXhQoxZWrosWUhUVSEze8v89GRKsM6YfZc09qFOEKDTAzUZV7FTXNp1-4rcH%22',
        'user_iam_verified': '%22%22',
        '__cf_bm': 'q1VDBIXpN4O4NXZjUbMTTcnoeP6zLoV5g3knElBwsMk-1766682298-1.0.1.1-V2MY0KFkwOQMLCC0pPWQFYoqXYcFKP.qQnQZyCMQ04a7pN4eUsqf45TyH.kWNtJ2N3y5GXi_aQBy5yymCI3nra5eXfCB2dG0ciqzJPsK2qo',
        'user': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....ZiK_JoNxY8qXt-0GBZrjx1UeALX6ZzvcutMGC_n-ouI',
        'cf_clearance': 'enRCK62Miaq76xY3hzvSc1DeKtUvNjIBYPXezY5BXMY-1766683093-1.2.1.1-JnOF6jJcqIoRmIRebKoKUG8WKpv8tfDJbn6dBNqpD9vkuH_yZfYvfmtANBBpPO1H_L3Iea_BYPzPY4IjXXByfZ2OB6eCo4XX.7zUOMtsiNfXp7gChxqiZtCp4Mwqxc31h7ct6hST2svRxHBcv1XU.rMUt6R36heLn0j1bDrF1rBF9dyMHeR7N4i5OiQiQEe1EfCKkbS9Ggyiq1iWR7vUGdSZ0wBQ57OHdhq7Zr0t0f4',
    }

    headers = {
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8',
        'accept-language': 'en-US,en;q=0.8',
        'cache-control': 'max-age=0',
        'priority': 'u=0, i',
        'referer': 'https://www.google.com/',
        'sec-ch-ua': '"Brave";v="143", "Chromium";v="143", "Not A(Brand";v="24"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'document',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-user': '?1',
        'sec-gpc': '1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36',
        # 'cookie': 'req-device-token=a4bdf11a-9a02-41ca-a466-aef7263aaf4d; webapp_token=%22Wk6NTixsCmW3wqPo-t2FZtJZhkr7kHu2aAvZO-jqEVoD2x73EOoCgs5MSHaJ2yZTm9zoA3ZaGF3i6cNYDR9jUWMdj6XSQBmLzEDHZJeevZrck-9sRXhQoxZWrosWUhUVSEze8v89GRKsM6YfZc09qFOEKDTAzUZV7FTXNp1-4rcH%22; user_iam_verified=%22%22; __cf_bm=q1VDBIXpN4O4NXZjUbMTTcnoeP6zLoV5g3knElBwsMk-1766682298-1.0.1.1-V2MY0KFkwOQMLCC0pPWQFYoqXYcFKP.qQnQZyCMQ04a7pN4eUsqf45TyH.kWNtJ2N3y5GXi_aQBy5yymCI3nra5eXfCB2dG0ciqzJPsK2qo; user=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....ZiK_JoNxY8qXt-0GBZrjx1UeALX6ZzvcutMGC_n-ouI; cf_clearance=enRCK62Miaq76xY3hzvSc1DeKtUvNjIBYPXezY5BXMY-1766683093-1.2.1.1-JnOF6jJcqIoRmIRebKoKUG8WKpv8tfDJbn6dBNqpD9vkuH_yZfYvfmtANBBpPO1H_L3Iea_BYPzPY4IjXXByfZ2OB6eCo4XX.7zUOMtsiNfXp7gChxqiZtCp4Mwqxc31h7ct6hST2svRxHBcv1XU.rMUt6R36heLn0j1bDrF1rBF9dyMHeR7N4i5OiQiQEe1EfCKkbS9Ggyiq1iWR7vUGdSZ0wBQ57OHdhq7Zr0t0f4',
    }

    return requests.get(url, cookies=cookies, headers=headers)


response = fetch('https://sa.aqar.fm/%D8%B9%D9%82%D8%A7%D8%B1%D8%A7%D8%AA/2')


html_docp2 = response.text

from bs4 import BeautifulSoup

assert "You have been blocked" not in response.text

soupp2 = BeautifulSoup(html_docp2)

soupp2
# Out:
# ________________________________________________________________________________
# [Memory] Calling __main__-C%3A-Users-rashe-AppData-Local-Temp-ipykernel-217808505.fetch...
# fetch('https://sa.aqar.fm/%D8%B9%D9%82%D8%A7%D8%B1%D8%A7%D8%AA/2')
# ____________________________________________________________fetch - 1.6s, 0.0min
# <!DOCTYPE html>
# ...

# %%
title_selector = '#__next > main > div > div._root__Szbd6 > div > div:nth-child(2) > div._container__Lu67A > div._list__Ka30R > div > a > div > div._content__W4gas > div._titleRow__1AWv1 > h4'

title_aq = soupp2.select(title_selector)

title_aq
# Out:
# [<h4 class="_inline__nh3gU"><svg fill="none" height="14" viewbox="0 0 12 14" width="12" xmlns="http://www.w3.org/2000/svg"><path d="M12 5.94049C12 6.48383 11.8906 7.05433 11.6719 7.652C11.4531 8.24968 11.1344 8.8715 10.7156 9.51746C10.2969 10.1634 9.775 10.8305 9.15 11.5188C8.525 12.207 7.80625 12.9133 6.99375 13.6378C6.85625 13.7585 6.7 13.8491 6.525 13.9094C6.35 13.9698 6.175 14 6 14C5.825 14 5.65 13.9698 5.475 13.9094C5.3 13.8491 5.14375 13.7585 5.00625 13.6378C4.19375 12.9133 3.475 12.207 2.85 11.5188C2.225 10.8305 1.70312 10.1634 1.28437 9.51746C0.865625 8.8715 0.546875 8.24968 0.328125 7.652C0.109375 7.05433 0 6.48383 0 5.94049C0 4.12937 0.603125 2.6865 1.80938 1.6119C3.01562 0.537301 4.4125 0 6 0C7.5875 0 8.98438 0.537301 10.1906 1.6119C11.3969 2.6865 12 4.12937 12 5.94049Z" fill="#52B44A"></path><path d="M5.07194 6.80269L4.46763 6.17489C4.29496 5.99552 4.09353 5.90583 3.86331 5.90583C3.63309 5.90583 3.43165 5.99552 3.25899 6.17489C3.08633 6.35426 3 6.56726 3 6.8139C3 7.06054 
# ...

# %%
all_selectorp1 = '#__next > main > div > div._root__Szbd6 > div > div:nth-child(2) > div._container__Lu67A > div._list__Ka30R > div'
containersp1 = soup.select(all_selectorp1)
len(containersp1)

containersp1[0]
# Out:
# <div><a class="" href="/%D8%AF%D9%88%D8%B1-%D9%84%D9%84%D8%A8%D9%8A%D8%B9/%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6/%D8%B4%D9%85%D8%A7%D9%84-%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6/%D8%AD%D9%8A-%D8%A7%D9%84%D9%86%D8%B1%D8%AC%D8%B3/%D8%B4%D8%A7%D8%B1%D8%B9-%D8%B4%D9%87%D9%8A%D8%AF-%D8%A7%D9%84%D8%AF%D9%8A%D9%86-%D8%AB%D9%85-%D8%A7%D9%84%D9%88%D8%B7%D9%86-%D9%81%D9%87%D8%AF-%D8%A5%D8%A8%D8%B1%D8%A7%D9%87%D9%8A%D9%85-%D8%B9%D9%84%D9%8A-%D8%A3%D8%A8-%D8%AD%D9%8A-%D8%A7%D9%84%D9%86%D8%B1%D8%AC%D8%B3-%D9%85%D8%AF%D9%8A%D9%86%D8%A9-%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6-%D9%85%D9%86%D8%B7%D9%82%D8%A9-%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6-6502998"><div class="_listingCard__PoR_B"><div class="_absolute__xO66o"></div><div class="_content__W4gas"><div class="_titleRow__1AWv1"><h4>دور للبيع في شارع شهيد الدين ثم الوطن فهد إبراهيم علي أب, حي النرجس, مدينة الرياض, منطقة الرياض</h4></div><div class="_price__X51mi"><span>1,500,000 <span class="icon-NewSaudiCurrency"></span></span></div><div class="_specs__nbsg
# ...

# %%
output_dict=[]
title_selector= "a > div > div._content__W4gas > div._titleRow__1AWv1"
price_selector= " a > div > div._content__W4gas > div._price__X51mi"
specs_selector= " a > div > div._content__W4gas > div._specs__nbsgm"
svg_selector= "div._spec__SIJiK > span.icon_icon___L1OO > img[src]"
description_selector= "a > div > div._content__W4gas > div._description__zVaD6"
location_selector= "a > div > div._content__W4gas > div._footer__CnldH"
for listing in containers:
    
    dict_item={
        "Title": listing.select_one(title_selector).get_text(strip=True) if listing.select_one(title_selector) else None,
        "Price": listing.select_one(price_selector).get_text(strip=True) if listing.select_one(price_selector) else None, 
        "Area": None,
        "Bedrooms": None,
        "Bathrooms": None,
        "Lounges": None,
        "Street Width": None,
        "Type": None,
        "Description": listing.select_one(description_selector).get_text(strip=True) if listing.select_one(description_selector) else None,
        "Location": listing.select_one(location_selector).get_text(strip=True) if listing.select_one(location_selector) else None, 
    }
    svg_map={
        "area.svg": "Area",
        "bed-king.svg": "Bedrooms",
        "bath.svg": "Bathrooms",
        "couch.svg": "Lounges",
        "street.svg": "Street Width",
        "pinned-note.svg": "Type",
    }
    
    for spec in listing.select("div._spec__SIJiK"):
        img = spec.select_one("img[src]")
        if not img:
            continue

        src = img.get("src", "")

        for svg_name, key in svg_map.items():
            if src.endswith(svg_name):
                value_text = spec.get_text(strip=True)

                digits = digits = "".join(ch for ch in value_text if ch in "0123456789")
                if digits:
                    dict_item[key] = int(digits)
                else:
                    dict_item[key] = value_text if value_text else None

    output_dict.append(dict_item)

output_dict_df = pd.DataFrame(output_dict)
output_dict_df
# Out:
#                                                 Title              Price  \
# 0   دور للبيع في شارع شهيد الدين ثم الوطن فهد إبرا...          1,500,000
# 1   فيلا للبيع في شارع 1809991, حي الروابي, مدينة ...          3,700,000
# 2   فيلا للبيع في شارع عذبة, حي حطين, مدينة الرياض...          4,900,000
# 3   فيلا للبيع في شارع خفاف بن ندبة, حي العليا, مد...          3,800,000
# 4   فيلا للبيع في شارع رقم 234, حي النرجس, مدينة ا...          4,750,000
# 5   أرض للبيع في شارع عز الدين ابن فهد, حي وادي جل...          1,764,000
# 6   شقة للبيع في شارع شارعام كلثوم بنت علي رضي الل...            680,000
# 7   شقة للإيجار في شارع رقم 272, حي الياسمين, مدين...   55,000 ريال/سنوي
# 8   شقة للإيجار في شارع أبي الفتح الرزاز, حي العار...       60,000خصم14%
# 9   غرفة للإيجار في شارع 6332463, حي عكرمة, مدينة ...              1,000
# 10  فيلا للبيع في شارع نافع بن صبرة, حي طيبة, مدين...          1,260,000
# 11  شقة للإيجار في شارع وادي الجوف, حي الصحافة, مد...   58,200 ريال/سنوي
# ...

# %%
output_dict=[]
title_selector= "a > div > div._content__W4gas > div._titleRow__1AWv1"
price_selector= " a > div > div._content__W4gas > div._price__X51mi"
specs_selector= " a > div > div._content__W4gas > div._specs__nbsgm"
svg_selector= "div._spec__SIJiK > span.icon_icon___L1OO > img[src]"
description_selector= "a > div > div._content__W4gas > div._description__zVaD6"
location_selector= "a > div > div._content__W4gas > div._footer__CnldH"
for listing in containers:
    
    dict_item={
        "Title": listing.select_one(title_selector).get_text(strip=True) if listing.select_one(title_selector) else None,
        "Price": listing.select_one(price_selector).get_text(strip=True) if listing.select_one(price_selector) else None, 
        "Area": None,
        "Bedrooms": None,
        "Bathrooms": None,
        "Lounges": None,
        "Street Width": None,
        "Type": None,
        "Description": listing.select_one(description_selector).get_text(strip=True) if listing.select_one(description_selector) else None,
        "Location": listing.select_one(location_selector).get_text(strip=True) if listing.select_one(location_selector) else None, 
    }
    svg_map={
        "area.svg": "Area",
        "bed-king.svg": "Bedrooms",
        "bath.svg": "Bathrooms",
        "couch.svg": "Lounges",
        "street.svg": "Street Width",
        "pinned-note.svg": "Type",
    }
    
    for spec in listing.select("div._spec__SIJiK"):
        img = spec.select_one("img[src]")
        if not img:
            continue

        src = img.get("src", "")

        for svg_name, key in svg_map.items():
            if src.endswith(svg_name):
                value_text = spec.get_text(strip=True)

                digits = digits = "".join(ch for ch in value_text if ch in "0123456789")
                if digits:
                    dict_item[key] = int(digits)
                else:
                    dict_item[key] = value_text if value_text else None

    output_dict.append(dict_item)

output_dict_df = pd.DataFrame(output_dict)
output_dict_df
# Out:
#                                                 Title              Price  \
# 0   دور للبيع في شارع شهيد الدين ثم الوطن فهد إبرا...          1,500,000
# 1   فيلا للبيع في شارع 1809991, حي الروابي, مدينة ...          3,700,000
# 2   فيلا للبيع في شارع عذبة, حي حطين, مدينة الرياض...          4,900,000
# 3   فيلا للبيع في شارع خفاف بن ندبة, حي العليا, مد...          3,800,000
# 4   فيلا للبيع في شارع رقم 234, حي النرجس, مدينة ا...          4,750,000
# 5   أرض للبيع في شارع عز الدين ابن فهد, حي وادي جل...          1,764,000
# 6   شقة للبيع في شارع شارعام كلثوم بنت علي رضي الل...            680,000
# 7   شقة للإيجار في شارع رقم 272, حي الياسمين, مدين...   55,000 ريال/سنوي
# 8   شقة للإيجار في شارع أبي الفتح الرزاز, حي العار...       60,000خصم14%
# 9   غرفة للإيجار في شارع 6332463, حي عكرمة, مدينة ...              1,000
# 10  فيلا للبيع في شارع نافع بن صبرة, حي طيبة, مدين...          1,260,000
# 11  شقة للإيجار في شارع وادي الجوف, حي الصحافة, مد...   58,200 ريال/سنوي
# ...

# %%
def extract_price(container):
    for child in container.descendants:   # نمشي على كل الأبناء
        if child.name in ["span", "div"]:
            text = child.get_text(strip=True)
            
            if text.replace(",", "").isdigit():
                value = int(text.replace(",", ""))
                if value >= 100000:   # فلترة (سعر حقيقي)
                    return value
    return None


listing_selector="#__next > main > div > div._root__Szbd6 > div > div:nth-child(2) > div._container__Lu67A > div._list__Ka30R > div"
listings = soup.select(listing_selector)
print(listings[0])
# Out:
# <div><a class="" href="/%D8%AF%D9%88%D8%B1-%D9%84%D9%84%D8%A8%D9%8A%D8%B9/%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6/%D8%B4%D9%85%D8%A7%D9%84-%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6/%D8%AD%D9%8A-%D8%A7%D9%84%D9%86%D8%B1%D8%AC%D8%B3/%D8%B4%D8%A7%D8%B1%D8%B9-%D8%B4%D9%87%D9%8A%D8%AF-%D8%A7%D9%84%D8%AF%D9%8A%D9%86-%D8%AB%D9%85-%D8%A7%D9%84%D9%88%D8%B7%D9%86-%D9%81%D9%87%D8%AF-%D8%A5%D8%A8%D8%B1%D8%A7%D9%87%D9%8A%D9%85-%D8%B9%D9%84%D9%8A-%D8%A3%D8%A8-%D8%AD%D9%8A-%D8%A7%D9%84%D9%86%D8%B1%D8%AC%D8%B3-%D9%85%D8%AF%D9%8A%D9%86%D8%A9-%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6-%D9%85%D9%86%D8%B7%D9%82%D8%A9-%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6-6502998"><div class="_listingCard__PoR_B"><div class="_absolute__xO66o"></div><div class="_content__W4gas"><div class="_titleRow__1AWv1"><h4>دور للبيع في شارع شهيد الدين ثم الوطن فهد إبراهيم علي أب, حي النرجس, مدينة الرياض, منطقة الرياض</h4></div><div class="_price__X51mi"><span>1,500,000 <span class="icon-NewSaudiCurrency"></span></span></div><div class="_specs__nbsg
# ...

# %%
extract_price(containers[19])
# Out:
# 2250000

# %%
titlel = []
for r in title_aq:
    titlel.append(r.get_text())
titlel
# Out:
# ['دور للبيع في شارع شهيد الدين ثم الوطن فهد إبراهيم علي أب, حي النرجس, مدينة الرياض, منطقة الرياض',
#  'فيلا للبيع في شارع عذبة, حي حطين, مدينة الرياض, منطقة الرياض',
#  'فيلا للبيع في شارع خفاف بن ندبة, حي العليا, مدينة الرياض, منطقة الرياض',
#  'فيلا للبيع في شارع 1809991, حي الروابي, مدينة الرياض, منطقة الرياض',
#  'دور للإيجار في شارع شداد بن أوس, حي العليا, مدينة الرياض, منطقة الرياض',
#  'شقة للبيع في شارع ربيعة القرشي, حي البوادي, مدينة جدة, منطقة مكة المكرمة',
#  'دور للبيع في شارع الجارود السلمي, حي عكاظ, مدينة الرياض, منطقة الرياض',
#  'فيلا للبيع في شارع ابن الغرس ، حي النيصية ، حائل ، منطقة حائل',
#  'أرض للبيع في شارع ابي بكر ، حي الفيحاء ، جدة ، جدة',
#  'عمارة للبيع في شارع عبدالسلام سحنون التنوخي ، حي الخالدية ، مكة ، منطقة مكة المكرمة',
#  'عمارة للبيع في حي ، شارع عمر ابن يوسف المقرئ ، حي بطحاء قريش ، مكة ، منطقة مكة المكرمة',
#  'عمارة للبيع في شارع أحمد بن عبد الواحد ، حي الكعكية ، مكة ، منطقة مكة المكرمة',
# ...
